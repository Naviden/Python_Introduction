# %% [markdown]
# # Functions

# %% [markdown]
# Python functions are blocks of code designed to perform a specific task, especially useful when that task needs to be reused in different parts of the code.

# %% [markdown]
# Suppose we want to perform some simple statistics on a list of numbers (don't focus on the details of the following code, we will explain them in the next chapters):

# %%
import numpy as np
np.random.seed(42)

data = np.random.rand(1,100_000).tolist()[0]
std = np.std(data)
mean = np.mean(data)
median = np.median(data)
min_val = min(data)
max_val = max(data)
for val in [std, mean, median, min_val, max_val]:
    print(val)

# %% [markdown]
# Ok, we did it! but what if we now want to repeat these processes for another list of numbers. We have two options:
#
# - Updating the data variable with a new list
# - Re-write all the steps for another list
#
# Both these solutions are bad! Or at least not Pythonic. The correct way to deal with such a task is to pack them as a function.

# %% [markdown]
# ## Built-in functions

# %% [markdown]
# Until this point, we used have many functions without knowing the exact definition of a function! We've seen:
#
# - print
# - len
# - max
# - min
#
# These are just few example of hundreds of functions that are part of core python language (it means to use them you don't need to import any library/package). A function always has the following structure:
#
# <img src="../Images/function.png" width="500">
#
# Parameters are inputs that functions may or may not need in order to perform their desired tasks. For example lats take a look at the `print` function which take a string as input and prints it.

# %%
print('My shiny text!')
print() # prints an empty line
print('X', 'Y', 'Z', sep='+++', end='\n')
print('X', 'Y', 'Z', '+++', '°°°')

# %% [markdown]
# you can see that print accepts zero , one or (technically) infinite number of parameters. Let's see another built-in function : `map`
#
# The `map` function returns a special iterable of type `map`:

# %%
my_list = ['-1.567', '0.2', '-65']
list(map(float, my_list))

# %% [markdown]
# map takes either no parameter and returns an empty list, or takes two or more parameters (let's say the function we want to apply and the iterable we want to apply function to). It means it won't work with just one parameter(function or iterable) and we will get a "TypeError" message.

# %% [markdown]
# <img src="../Images/student.svg"   width="30" align="left">

# %% [markdown]
# **YOUR TURN :** using `map` and `abs` functions, create a list with the absolute value of the list's items.

# %%
(\   .-.   .-.   .-.   .-.   .-.   .-.   .-.   .-.   /_")
 \\_//^\\_//^\\_//^\\_//^\\_//^\\_//^\\_//^\\_//^\\_//
  `"`   `"`   `"`   `"`   `"`   `"`   `"`   `"`   `"`

# %% [markdown]
# <details>
#     <summary>Solution</summary>
#     <code>
# new_list = [-1, 5.5, -9, -123, 65]
# list(map(abs, new_list))
# 	</code>
# </details>

# %% [markdown]
# ## Custom functions

# %% [markdown]
# Although there are many built-in and third-party modules and packages available, some tasks are too specific to have a ready-made solution. In these cases, which happen quite often, we need to write our own functions. For example, think back to the simple statistics calculation we saw at the beginning of the "functions" section:

# %%
def simple_stat(data, log=True):
    """Calculating simple statistics of a given list.
    
    For the the given list of numbers, calculates standard deviation, 
    Mean, Median, Minimum and Maximum statistics.

    Args:
        data : A list of numerical data.
        log: If True, prints a simple report.
        
    Returns:
        Return a list of the given numbers
    """
    std = np.std(data)
    mean = np.mean(data)
    median = np.median(data)
    min_val = min(data)
    max_val = max(data)
    
    vals = [std, mean, median, min_val, max_val]
    names = ['Standard deviation', 'Mean', 'Median', 'Min', 'Max']
    
    if log:
        for name, val in zip(names, vals):
            print(f'{name} : {val}')
    return vals

# %%
np.random.seed(42)

data = np.random.rand(1,100_000).tolist()[0]
results = simple_stat(data)

# %% [markdown]
# Following figure shows the structure of a custom function:
#
# <img src="../Images/function_detail.png" width="900">

# %% [markdown]
# <img src="../Images/student.svg"   width="30" align="left">

# %% [markdown]
# **YOUR TURN :**
#
# 1. Using the `round` function, modify `simple_stat` in a way that returns the 2-digit rounded values;
# 2. Add `range` statistics to results.

# %%
(\   .-.   .-.   .-.   .-.   .-.   .-.   .-.   .-.   /_")
 \\_//^\\_//^\\_//^\\_//^\\_//^\\_//^\\_//^\\_//^\\_//
  `"`   `"`   `"`   `"`   `"`   `"`   `"`   `"`   `"`

# %% [markdown]
# <details>
#     <summary>Solution</summary>
#     <code>
#         def simple_stat(data, log=True):
#             std = np.std(data)
#             mean = np.mean(data)
#             median = np.median(data)
#             min_val = min(data)
#             max_val = max(data)
#             max_min_range = max_val - min_val
#
#             vals = [std, mean, median, min_val, max_val, max_min_range]
#             names = ['Standard deviation', 'Mean', 'Median', 'Min', 'Max', 'Range']
#
#             if log:
#                 for name, val in zip(names, vals):
#                     print(f'{name} : {round(val, 2)}')
#
#             return vals
#
#             data = np.random.rand(1,100_000).tolist()[0]
#             results = simple_stat(data)
#     </code>
# </details>

# %% [markdown]
# ## Lambda functions

# %% [markdown]
# Lambda functions are smaller and simpler version of normal functions, which come handy when we use the **functional programming** features of Python. Providing a technical definition of functional programming is way beyond the scope of our mini-course but, in a nutshell, it means using functions as arguments of other functions.
# Let's first consider the example of `map` function we saw:

# %%
help(map)

# %%
my_list = ['-1.567', '0.2', '-65']
print(f"A list of strings representing numbers:\n{my_list}")
float_list = list(map(float, my_list))
print(f"After using map, applying the float function to each element:\n{float_list}")

# %% [markdown]
# Now suppose that, in addition to converting the data types from str to float, we also want to add 100 to each value. Remember how the map function works? It applies the first argument (in this case, float) to each element of the sequence provided as the second argument (in our example: my_list). So we need to replace float with something that both converts the value to a float and adds 100 to it. This *something* should be either a type or a function.
#
# Based on what we've learned so far, let's create a custom function that does exactly what we want:

# %%
def float_plus_100(number):
    """Converts the given number to float and adds 100 to it
    
    args:
        number : int or float
        
    returns:
        float
    """
    return float(number) + 100

# %% [markdown]
# Ok, our function is ready. Let's test it:

# %%
float_plus_100('3.14')

# %% [markdown]
# It works! Now we can add it to our map function:

# %%
list(map(float_plus_100, my_list))

# %% [markdown]
# We did it! The only problem is that, in order to perform such a simple task, we had to define a function which probably we're not going to use again! That's why lambda functions exist! Let's re-write or code using lambda:

# %%
list(map(lambda x : float(x) + 100, my_list))

# %% [markdown]
# As you can see, we did the same thing without defining any function. In the following figure you can see the comparison between a lambda function and its corespondent function:
#
# <img src="../Images/lambda.png" width="800">

# %% [markdown]
# Such a comparison may indicate that lambda functions are the definite choice but in reality, we use functions way more than we use lambdas since dealing with real data, often we should perform tasks that are too complex to be written as a lambda function.
